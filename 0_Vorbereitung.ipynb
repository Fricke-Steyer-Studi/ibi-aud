# %% [markdown]
# # Vorbereitung
#
# ## Lernziele
#
# <div class="alert alert-info">
#
# - Source-Code-Management-Systeme (SCM) wie GitLab bedienen können
# - Jupyter-Notebooks öffnen und ausführen können
#
# </div>
#
# ## Material
#
# Hier finden Sie Hinweise zur Vorbereitung auf das Modul und zur Installation benötigter Software. Sie sollten für die Vorbereitung ca. zwei Stunden einplanen. Bitte versuchen Sie auf jeden Fall, die [Aufgabe](#Aufgabe) am Ende der Seite erfolgreich abzuschließen. Melden Sie sich, falls dabei Probleme auftreten.
#
# ### GitLab
#
# Das Lernmaterial in diesem Kurs wird Ihnen in *GitLab* bereitgestellt, einem sogenannten *Source-Code-Management-System* (SCM). Solche Systeme sind zum kollaborativen Arbeiten an (typischerweise Software-)Projekten gedacht.  Programmierer:innen können darin Quellcode abspeichern, Änderungen verfolgen und rückgängig machen, Fehler melden und Code dokumentieren. GitLab ist freie Software und wir nutzen die Instanz auf dem Server http://scm.cms.hu-berlin.de/ die uns vom Computer- und Medienservice (CMS) der Humboldt-Universität zu Berlin bereitgestellt wird.
#
# Ein wesentlicher Baustein von GitLab ist *Git*, ein System zur *verteilten Verwaltung von Dateiversionen*.
#
# <div class="alert alert-success">
#
# Bitte machen Sie sich mit GitLab vertraut, zum Beispiel mit Hilfe der kurzen [Einführung zu GitLab](https://pages.cms.hu-berlin.de/cms-webtech/gitlab-documentation/docs/home/) vom CMS.
#
# Library Carpentry bietet Ihnen eine [Einführung zu Git](https://librarycarpentry.org/lc-git/), die allerdings über das hinausgeht, was Sie zwingend für diesen Kurs benötigen. Sie können diesen Kurs auch herunterladen, ohne Git zu installieren und **Sie benötigen keinen GitHub-Account.**
#
# </div>
#
# Wenn Sie *Fehler* in den Kursmaterialien finden oder *Hinweise zur Verbesserung* haben, können Sie diese im Menü links unter [Issues](https://scm.cms.hu-berlin.de/ibi/damostin/issues) hinzufügen.
#
# Sie können die Möglichkeiten des Systems später auch für Ihre *Haus- oder Abschlussarbeiten* nutzen, indem Sie [ein eigenes Projekt anlegen](https://scm.cms.hu-berlin.de/projects/new) und dort Ihre Dateien versioniert abspeichern. Dazu sollten Sie sich mit der Versionsverwaltungssoftware [Git](https://de.wikipedia.org/wiki/Git) vertraut machen.
#
# ![Git](https://imgs.xkcd.com/comics/git.png "If that doesn't fix it, git.txt contains the phone number of a friend of mine who understands git. Just wait through a few minutes of 'It's really pretty simple, just think of branches as...' and eventually you'll learn the commands that will fix everything.")
# © [Randall Munroe](https://xkcd.com/1597/) / CC-BY-NC 2.5

# %% [markdown]
# ### Jupyter und Python
#
# Im Kurs wird es regelmäßig kleine interaktive Beispiele und Übungen in der Programmiersprache [Python](https://www.python.org/) geben. Dafür werden die Kursmaterialien in Form sogenannter [Jupyter Notebooks](https://jupyter.org/) bereitgestellt. Dies sind interaktive Webseiten, die Programmcode und Dokumentation enthalten können. Auch diese Seite ist ein Jupyter Notebook.
#
# <div class="alert alert-success">
#
# Wenn Sie möchten, können Sie begleitend zu diesem Modul einen [Programmierkurs in Python](https://scm.cms.hu-berlin.de/ibi/python) belegen. Dieser basiert ebenfalls auf Jupyter Notebooks und ist in GitLab verfügbar.
#
# Lesen Sie sich die [Tipps zur Einrichtung von Python und Jupyter](https://scm.cms.hu-berlin.de/ibi/python) auf der Startseite des Kurses durch und folgen Sie den Hinweisen zur Installation der für ihr Betriebssystem geeigneten Variante von Jupyter. **Installieren Sie Jupyter (i.A. mittels Anaconda) auf Ihrem Rechner.**
#
# Im Web finden Sie viele weitere Anleitungen zum Einrichten und Nutzen von Jupyter, z.B. [diese von der TU Hamburg-Harburg](https://fizban05.rz.tu-harburg.de/itbh-inf-wise201718/veranstaltungsskript-inf-wise201718/material/sitzungsmaterial/einrichtung-byod-python.html).
#
# </div>

# %% [markdown]
# ### Arbeiten mit diesem Kurs
#
# Sie können sich die Jupyter Notebooks direkt in GitLab in Ihrem Web-Browser anschauen. Dabei fehlen jedoch Formatierungen und Bilder und vor allem können Sie die interaktiven Beispiele nicht ausprobieren und einige der Aufgaben nicht lösen. Daher müssen Sie sich die Notebooks auf Ihren Rechner herunterladen und in Jupyter starten. Dazu gibt es im Wesentlichen drei Möglichkeiten:
#
# #### Notebooks einzeln herunterladen
#
# Sie können jedes Notebook einzeln herunterladen, abspeichern und in Jupyter öffnen. Dazu ist es wichtig, dass Sie das Notebook selbst herunterladen und nicht die GitLab-Webseite.  Klicken Sie dazu auf der Seite mit dem jeweiligen Notebook **mit der rechten Maustaste** auf den Button "Open Raw" und speichern Sie die geöffnete Datei, indem Sie **"Ziel speichern unter ..."** (oder "Link speichern unter ...") wählen:
# ![Open raw](https://amor.cms.hu-berlin.de/~jaeschkr/teaching/damostin/open_raw.png)
# *(Hinweis: dies funktioniert oft nicht im Edge-Browser, verwenden Sie also ggf. Firefox, Chrome oder Opera.)*
#
# Der Vorteil dieser Variante ist, dass Sie aktualisierte Notebooks leicht einzeln herunterladen können und dass Sie keine weitere Software benötigen.
#
# #### Gesamtes Projekt herunterladen
#
# Sie können [auf der Projektstartseite](https://scm.cms.hu-berlin.de/ibi/damostin) alle Notebooks auf einmal [als ZIP-Datei herunterladen](https://scm.cms.hu-berlin.de/ibi/damostin/-/archive/master/damostin-master.zip) und auf Ihrem Rechner in ein Verzeichnis entpacken.
#
# ![Open raw](https://amor.cms.hu-berlin.de/~jaeschkr/teaching/damostin/download.png)
#
# Der Vorteil dieser Variante ist, dass Sie alle Inhalte auf einmal in einem Verzeichnis haben. Wenn Notebooks geändert oder hinzugefügt werden, müssen Sie diesen Schritt wiederholen oder diese Notebooks einzeln herunterladen.
#
# #### Projekt per Git synchronisieren
#
# Fortgeschrittene können sich dieses Projekt auch auf ihrem eigenen Rechner mittels Git klonen und dann immer die aktuellste Version der Notebooks herunterladen. Dazu müssen Sie Git installieren und sich damit vertraut machen (die [Einführung zu Git von Library Carpentry](https://librarycarpentry.org/lc-git/) kann Ihnen dabei weiterhelfen).
#
# <div class="alert alert-danger">
#
# #### Hinweis
# Im Verlauf des Kurses werden Sie die Notebooks verändern und ergänzen. **Nutzen Sie die Notebooks als "lebendiges" Lernmaterial, indem Sie Notizen, Beispiele, etc. hinzufügen.**
#
# Achten Sie beim Aktualisieren der Notebooks darauf, dass Ihre Änderungen nicht verloren gehen. Bei der ersten Variante geht das recht einfach, indem Sie nur neue Notebooks herunterladen. Schwieriger ist es bei Git, da Ihre Änderungen ggf. mit Aktualisierungen der Notebooks kollidieren. Hier müssen Sie ggf. einen Merge-Schritt durchführen. Konsultieren Sie dazu die Dokumentation zu Git oder [eines](https://git-scm.com/docs/gittutorial) der zahlreichen Tutorials.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# ### Aufgabe
#
# Mit Hilfe dieser Aufgabe können Sie prüfen, ob Sie alles richtig installiert und verstanden haben:
#
# 1. Laden Sie dieses Notebook wie oben beschrieben herunter (und merken Sie sich den Ordner, in dem Sie es abgespeichert haben).
# 1. Starten Sie *Jupyter Notebook* (i.A. per *Anaconda Navigator*).
# 3. Navigieren Sie in Jupyter zum Ordner, in dem Sie das Notebook gespeichert haben und öffnen Sie es.
# 3. Rufen Sie durch Drücken der Taste "h" die Hilfefunktion auf und machen Sie sich mit einigen Tastenkombinationen vertraut. (Ggf. müssen Sie vor dem Drücken von "h" erst die Taste "ESC" drücken.)
# 2. Fügen Sie am Ende des Notebooks eine neue "Zelle" ein. (Nutzen Sie dafür den Punkt "Insert" im Menü oder die Taste "b".)
# 4. Fügen Sie in der neuen Zelle den Text `print("Hello World!")` ein.
# 5. Führen Sie diese Zelle aus. (Nutzen Sie dafür das Menü oder die Tastenkombination "STRG-ENTER".)
# 6. Unter der Zelle sollte die Ausgabe "Hello World!" erscheinen.
#
# **Falls Sie bei einem der Punkte nicht weiterkommen oder auf ein Problem stoßen, melden Sie sich bitte rechtzeitig** (spätestens eine Woche vor dem ersten Treffen).
#
# Beim ersten Treffen gehen wir davon aus, dass alle Teilnehmer:innen Jupyter Notebooks bearbeiten und ausführen können.
#
# </div>

# %% [markdown]
# ## Problembehebung
#
# Hier sammeln wir ein Probleme, die häufiger auftreten. Schauen Sie zunächst, ob Ihres dabei ist bzw. ob die Lösungsvorschläge Ihnen weiterhelfen.
#
# ### Fehlermeldung "Unreadable Notebook" von Jupyter
#
# Falls Sie eine Fehlermeldung der Art
# ```
# Unreadable Notebook: /home/[PFAD]/Vorbereitung.ipynb NotJSONError('Notebook does not appear to be JSON: \'<!DOCTYPE html>\\n<html class="with-syst...')
# ```
# erhalten, haben Sie vermutlich das Notebook mit Ihrem Webbrowser als HTML-Datei abgespeichert. Achten Sie darauf, es wie oben beschrieben mittels des "Open raw"-Links abzuspeichern. Alternativ können Sie auch das ganze Projekt als ZIP-Datei herunterladen.
